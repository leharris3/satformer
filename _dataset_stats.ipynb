# %%
import torch
from src.dataloader.challenge_one_dataloader import Sat2RadDataset
from tqdm import tqdm


NUM_SAMPELS = 1000
ds = Sat2RadDataset(split="train")

X_maxs  = []
y_maxs  = []
targets = []

for i in tqdm(range(NUM_SAMPELS)):
    item  = ds[i]
    y_reg = item["y_reg"]
    targets.append(y_reg.item())
# Out:
# Loading dataset...: 100%|██████████| 7/7 [00:00<00:00, 116.77it/s]
#   3%|▎         | 28/1000 [00:16<09:37,  1.68it/s]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[1], line 14
#      11 targets = []
#      13 for i in tqdm(range(NUM_SAMPELS)):
# ---> 14     item  = ds[i]
#      15     y_reg = item["y_reg"]
#      16     targets.append(y_reg.item())
#
# File /playpen-ssd/levi/w4c/w4c-25/src/dataloader/challenge_one_dataloader.py:351, in Sat2RadDataset.__getitem__(self, index)
#     348 def __getitem__(self, index: int) -> dict:
#     350     if self.split in ["train", "val"]:
# --> 351         return self.get_item_train_val(index)
#     352     elif self.split == "test":
#     353         return self.get_item_test(index)
#
# File /playpen-ssd/levi/w4c/w4c-25/src/dataloader/challenge_one_dataloader.py:193, in Sat2RadDataset.get_item_train_val(self, index)
#     189 X = X.mean(dim=0)
#     191 # label: 4H proceeding rainfall
#     192 # [T=16, C=1, H=252, W=252]
# --> 193 y = opera_ds[start_T+4:start_T+20].to_numpy()
#     194 y = torch.Tensor(y)
#     196 # NOTE: clip @0; it can't rain a negative amount; large negative values in our datasets
#
# File /playpen-ssd/levi/miniconda3/envs/wfc/lib/python3.14/site-packages/xarray/core/dataarray.py:814, in DataArray.to_numpy(self)
#     803 def to_numpy(self) -> np.ndarray:
#     804     """
#     805     Coerces wrapped data to numpy and returns a numpy.ndarray.
#     806
#    (...)    812     DataArray.data
#     813     """
# --> 814     return self.variable.to_numpy()
#
# File /playpen-ssd/levi/miniconda3/envs/wfc/lib/python3.14/site-packages/xarray/namedarray/core.py:858, in NamedArray.to_numpy(self)
#     856 """Coerces wrapped data to numpy and returns a numpy.ndarray"""
#     857 # TODO an entrypoint so array libraries can choose coercion method?
# --> 858 return to_numpy(self._data)
#
# File /playpen-ssd/levi/miniconda3/envs/wfc/lib/python3.14/site-packages/xarray/namedarray/pycompat.py:112, in to_numpy(data, **kwargs)
#     109     pass
#     111 if isinstance(data, ExplicitlyIndexed):
# --> 112     data = data.get_duck_array()  # type: ignore[no-untyped-call]
#     114 # TODO first attempt to call .to_numpy() once some libraries implement it
#     115 if is_chunked_array(data):
#
# File /playpen-ssd/levi/miniconda3/envs/wfc/lib/python3.14/site-packages/xarray/core/indexing.py:943, in MemoryCachedArray.get_duck_array(self)
#     942 def get_duck_array(self):
# --> 943     duck_array = self.array.get_duck_array()
#     944     # ensure the array object is cached in-memory
#     945     self.array = as_indexable(duck_array)
#
# File /playpen-ssd/levi/miniconda3/envs/wfc/lib/python3.14/site-packages/xarray/core/indexing.py:897, in CopyOnWriteArray.get_duck_array(self)
#     896 def get_duck_array(self):
# --> 897     return self.array.get_duck_array()
#
# File /playpen-ssd/levi/miniconda3/envs/wfc/lib/python3.14/site-packages/xarray/core/indexing.py:737, in LazilyIndexedArray.get_duck_array(self)
#     734 from xarray.backends.common import BackendArray
#     736 if isinstance(self.array, BackendArray):
# --> 737     array = self.array[self.key]
#     738 else:
#     739     array = apply_indexer(self.array, self.key)
#
# File /playpen-ssd/levi/miniconda3/envs/wfc/lib/python3.14/site-packages/xarray/backends/h5netcdf_.py:65, in H5NetCDFArrayWrapper.__getitem__(self, key)
#      64 def __getitem__(self, key):
# ---> 65     return indexing.explicit_indexing_adapter(
#      66         key, self.shape, indexing.IndexingSupport.OUTER_1VECTOR, self._getitem
#      67     )
#
# File /playpen-ssd/levi/miniconda3/envs/wfc/lib/python3.14/site-packages/xarray/core/indexing.py:1129, in explicit_indexing_adapter(key, shape, indexing_support, raw_indexing_method)
#    1107 """Support explicit indexing by delegating to a raw indexing method.
#    1108
#    1109 Outer and/or vectorized indexers are supported by indexing a second time
#    (...)   1126 Indexing result, in the form of a duck numpy-array.
#    1127 """
#    1128 raw_key, numpy_indices = decompose_indexer(key, shape, indexing_support)
# -> 1129 result = raw_indexing_method(raw_key.tuple)
#    1130 if numpy_indices.tuple:
#    1131     # index the loaded duck array
#    1132     indexable = as_indexable(result)
#
# File /playpen-ssd/levi/miniconda3/envs/wfc/lib/python3.14/site-packages/xarray/backends/h5netcdf_.py:72, in H5NetCDFArrayWrapper._getitem(self, key)
#      70 with self.datastore.lock:
#      71     array = self.get_array(needs_lock=False)
# ---> 72     return array[key]
#
# File /playpen-ssd/levi/miniconda3/envs/wfc/lib/python3.14/site-packages/h5netcdf/core.py:601, in BaseVariable.__getitem__(self, key)
#     599     return h5ds[key].view(view)
#     600 else:
# --> 601     return h5ds[key]
#
# File h5py/_objects.pyx:54, in h5py._objects.with_phil.wrapper()
#
# File h5py/_objects.pyx:55, in h5py._objects.with_phil.wrapper()
#
# File /playpen-ssd/levi/miniconda3/envs/wfc/lib/python3.14/site-packages/h5py/_hl/dataset.py:840, in Dataset.__getitem__(self, args, new_dtype)
#     838 if self._fast_read_ok and (new_dtype is None):
#     839     try:
# --> 840         return self._fast_reader.read(args)
#     841     except TypeError:
#     842         pass  # Fall back to Python read pathway below
#
# KeyboardInterrupt:

# %%
import matplotlib.pyplot as plt

plt.hist(targets);
max(targets)
# Out:
# 7844.43994140625
