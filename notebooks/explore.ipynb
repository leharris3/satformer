# %%
import pandas as pd
import h5py


file_path = "/playpen-ssd/levi/w4c/w4c-25/weather4cast_data/w4c25/2019/OPERA/boxi_0015.train.rates.crop.h5"


with h5py.File(file_path, "r") as f:
    
    # List top-level groups/datasets
    print("Keys:", list(f.keys()))
    
    # Example: access a dataset
    dataset_name = list(f.keys())[0]  # or replace with a known name
    data = f[dataset_name][:]
    print("Shape:", data.shape)
    print("Data type:", data.dtype)

# %%
import xarray as xr


fp1 = "/playpen-ssd/levi/w4c/w4c-25/weather4cast_data/w4c25/2019/OPERA/boxi_0015.train.rates.crop.h5"

# This is extremely fast - it only reads metadata, not data.
ds = xr.open_dataset(file_path, cache=False).load()

# Print a summary of the dataset (variables, dimensions, coordinates)
print(ds)

# You can still access the data as a lazy-loaded array
# (Replace 'variable_name' with the actual name from the printout)
data_array = ds['rates.crop']
print(data_array.shape)

# %%
import numpy as np


ds = xr.open_dataset(file_path, cache=False)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[4], line 5
#       1 import numpy as np
#       4 ds = xr.open_dataset(file_path, cache=False)
# ----> 5 arr = np.array(data)
#       6 arr.shape
#
# NameError: name 'data' is not defined

# %%
# [B, C, H, W]
sample = arr[2005, :, :, :]
print(sample.min(), sample.max(), "\n", sample.shape)

# we're going to assume that OPERA radar-rain rates should be clipped @0.0
clipped_sample = sample.clip(0)
print(clipped_sample.min(), clipped_sample.max(), "\n", clipped_sample.shape)

# %%
import torch
import matplotlib.pyplot as plt


img_like_cs = torch.Tensor(clipped_sample).permute(1, 2, 0);
# img_like_cs_norm = (img_like_cs - img_like_cs.min()) / (img_like_cs.max() - img_like_cs.min())

# an exmaple of OPERA radar rain-rate data
plt.imshow(img_like_cs, cmap='viridis');
plt.colorbar()
plt.show()

# %%
import pandas as pd


df = pd.read_csv("/playpen-ssd/levi/w4c/w4c-25/weather4cast_data/challenge_one/roxi_0008.cum1test_dictionary.csv")
df
# Out:
#    Case-id  year  slot-start  slot-end  x-top-left  x-bottom-right  \
# 0     TUR1  2019           0         4         663             695
# 1     SPT1  2019           4         8         756             788
# 2     KLA1  2019           8        12        1057            1089
# 3     OUL1  2019          12        16         370             402
# 4     TAM1  2019          16        20         594             626
# 5     JYV1  2019          20        24         552             584
# 6     TAL1  2019          24        28         757             789
# 7     KLA2  2019          28        32        1057            1089
# 8     SPT2  2019          32        36         756             788
# 9     OUL2  2019          36        40         370             402
# 10    HEL1  2019          40        44         699             731
# 11    HEL2  2019          44        48         699             731
# 12    TUR2  2019          48        52         663             695
# ...
