# %%
import torch
from src.dataloader.challenge_one_dataloader import Sat2RadDataset
from tqdm import tqdm


ds = Sat2RadDataset(split="train")
dl = torch.utils.data.DataLoader(ds, batch_size=16, num_workers=16)
# Out:
# Loading dataset...:   0%|          | 0/7 [00:00<?, ?it/s]
# Loading dataset...: 100%|██████████| 7/7 [00:00<00:00, 51.29it/s]

# %%
labels = None
for sample in tqdm(dl):
    y = sample["y_reg_norm"]
    if labels == None: labels = y.squeeze()
    else: labels = torch.cat([labels, y.squeeze()]); break
# Out:
#   0%|          | 1/512 [00:29<4:07:36, 29.07s/it]

# %%
labels.shape
# Out:
# torch.Size([32])

# %%
import matplotlib.pyplot as plt

plt.hist(y.squeeze());

# %%
items_per_bins = [1.7924e+04, 1.0090e+03, 5.9500e+02, 4.5500e+02, 4.2000e+02,
       3.1500e+02, 2.8500e+02, 2.9000e+02, 2.1400e+02, 2.0200e+02,
       2.0000e+02, 1.5700e+02, 1.6000e+02, 1.5800e+02, 1.2900e+02,
       1.1100e+02, 1.2100e+02, 1.0500e+02, 1.1600e+02, 1.2600e+02,
       1.0200e+02, 8.3000e+01, 8.7000e+01, 8.7000e+01, 6.7000e+01,
       5.3000e+01, 5.6000e+01, 6.9000e+01, 4.6000e+01, 3.7000e+01,
       4.4000e+01, 4.0000e+01, 4.2000e+01, 3.4000e+01, 3.8000e+01,
       3.2000e+01, 2.9000e+01, 2.3000e+01, 1.8000e+01, 3.0000e+01,
       2.7000e+01, 2.0000e+01, 2.2000e+01, 2.9000e+01, 1.8000e+01,
       2.5000e+01, 9.0000e+00, 1.9000e+01, 1.8000e+01, 1.3000e+01,
       9.0000e+00, 1.7000e+01, 1.4000e+01, 1.2000e+01, 8.0000e+00,
       7.0000e+00, 1.3000e+01, 7.0000e+00, 1.0000e+01, 5.0000e+00,
       8.0000e+00, 5.0000e+00, 8.0000e+00, 3.0000e+00, 8.0000e+00,
       6.0000e+00, 9.0000e+00, 6.0000e+00, 6.0000e+00, 3.0000e+00,
       5.0000e+00, 3.0000e+00, 7.0000e+00, 4.0000e+00, 5.0000e+00,
       3.0000e+00, 1.0000e+00, 6.0000e+00, 4.0000e+00, 3.0000e+00,
       4.0000e+00, 4.0000e+00, 2.0000e+00, 2.0000e+00, 1.0000e+00,
       2.0000e+00, 2.0000e+00, 4.0000e+00, 0.0000e+00, 2.0000e+00,
       4.0000e+00, 1.0000e+00, 8.0000e+00, 0.0000e+00, 0.0000e+00,
       1.0000e+00, 3.0000e+00, 1.0000e+00, 3.0000e+00, 3.0000e+00,
       1.0000e+00, 0.0000e+00, 1.0000e+00, 3.0000e+00, 0.0000e+00,
       2.0000e+00, 0.0000e+00, 0.0000e+00, 0.0000e+00, 1.0000e+00,
       0.0000e+00, 0.0000e+00, 1.0000e+00, 0.0000e+00, 0.0000e+00,
       0.0000e+00, 0.0000e+00, 0.0000e+00, 0.0000e+00, 0.0000e+00,
       1.0000e+00, 0.0000e+00, 0.0000e+00, 0.0000e+00, 1.0000e+00,
       0.0000e+00, 0.0000e+00, 0.0000e+00, 1.0000e+00]

cmf = [0.        , 0.00772506, 0.01545012, 0.02317518, 0.03090023,
       0.03862529, 0.04635035, 0.05407541, 0.06180047, 0.06952552,
       0.07725058, 0.08497564, 0.0927007 , 0.10042576, 0.10815082,
       0.11587588, 0.12360094, 0.13132599, 0.13905105, 0.14677611,
       0.15450117, 0.16222623, 0.16995129, 0.17767635, 0.18540141,
       0.19312647, 0.20085153, 0.20857657, 0.21630163, 0.22402669,
       0.23175175, 0.23947681, 0.24720187, 0.25492692, 0.26265198,
       0.27037704, 0.2781021 , 0.28582716, 0.29355222, 0.30127728,
       0.30900234, 0.3167274 , 0.32445246, 0.33217752, 0.33990258,
       0.34762764, 0.3553527 , 0.36307776, 0.37080282, 0.37852788,
       0.38625294, 0.393978  , 0.40170306, 0.40942812, 0.41715315,
       0.42487821, 0.43260327, 0.44032833, 0.44805339, 0.45577845,
       0.46350351, 0.47122857, 0.47895363, 0.48667869, 0.49440375,
       0.50212878, 0.50985384, 0.5175789 , 0.52530396, 0.53302902,
       0.54075408, 0.54847914, 0.5562042 , 0.56392926, 0.57165432,
       0.57937938, 0.58710444, 0.5948295 , 0.60255456, 0.61027962,
       0.61800468, 0.62572974, 0.6334548 , 0.64117986, 0.64890492,
       0.65662998, 0.66435504, 0.6720801 , 0.67980516, 0.68753022,
       0.69525528, 0.70298034, 0.7107054 , 0.71843046, 0.72615552,
       0.73388058, 0.74160564, 0.7493307 , 0.75705576, 0.76478082,
       0.77250588, 0.78023094, 0.787956  , 0.79568106, 0.80340612,
       0.81113118, 0.81885624, 0.82658124, 0.8343063 , 0.84203136,
       0.84975642, 0.85748148, 0.86520654, 0.8729316 , 0.88065666,
       0.88838172, 0.89610678, 0.90383184, 0.9115569 , 0.91928196,
       0.92700702, 0.93473208, 0.94245714, 0.9501822 , 0.95790726,
       0.96563232, 0.97335738, 0.98108244, 0.9888075 , 0.99653256]

# %%
import torch
import numpy as np


arr = torch.load("/playpen-ssd/levi/w4c/w4c-25/y_reg_norms.pth").numpy()

# %%
arr.max()
# Out:
# np.float32(1.9910212)

# %%
np.arange(0, arr.max(), arr.max() / 128)
# Out:
# array([0.        , 0.01555485, 0.03110971, 0.04666456, 0.06221941,
#        0.07777426, 0.09332912, 0.10888397, 0.12443882, 0.13999368,
#        0.15554853, 0.17110338, 0.18665823, 0.20221309, 0.21776794,
#        0.23332279, 0.24887764, 0.2644325 , 0.27998735, 0.2955422 ,
#        0.31109706, 0.32665191, 0.34220676, 0.35776161, 0.37331647,
#        0.38887132, 0.40442617, 0.41998103, 0.43553588, 0.45109073,
#        0.46664558, 0.48220044, 0.49775529, 0.51331014, 0.52886499,
#        0.54441985, 0.5599747 , 0.57552955, 0.59108441, 0.60663926,
#        0.62219411, 0.63774896, 0.65330382, 0.66885867, 0.68441352,
#        0.69996838, 0.71552323, 0.73107808, 0.74663293, 0.76218779,
#        0.77774264, 0.79329749, 0.80885234, 0.8244072 , 0.83996205,
#        0.8555169 , 0.87107176, 0.88662661, 0.90218146, 0.91773631,
#        0.93329117, 0.94884602, 0.96440087, 0.97995573, 0.99551058,
#        1.01106543, 1.02662028, 1.04217514, 1.05772999, 1.07328484,
#        1.08883969, 1.10439455, 1.1199494 , 1.13550425, 1.15105911,
#        1.16661396, 1.18216881, 1.19772366, 1.21327852, 1.22883337,
#        1.24438822, 1.25994308, 1.27549793, 1.29105278, 1.30660763,
#        1.32216249, 1.33771734, 1.35327219, 1.36882704, 1.3843819 ,
#        1.39993675, 1.4154916 , 1.43104646, 1.44660131, 1.46215616,
#        1.47771101, 1.49326587, 1.50882072, 1.52437557, 1.53993043,
#        1.55548528, 1.57104013, 1.58659498, 1.60214984, 1.61770469,
#        1.63325954, 1.6488144 , 1.66436925, 1.6799241 , 1.69547895,
#        1.71103381, 1.72658866, 1.74214351, 1.75769836, 1.77325322,
#        1.78880807, 1.80436292, 1.81991778, 1.83547263, 1.85102748,
#        1.86658233, 1.88213719, 1.89769204, 1.91324689, 1.92880175,
#        1.9443566 , 1.95991145, 1.9754663 ])

# %%
import matplotlib.pyplot as plt


plt.hist(arr, bins=129, log=True)
plt.grid()

# %%
import torch
import numpy as np
import matplotlib.pyplot as plt


fp = "/playpen-ssd/levi/w4c/w4c-25/y_reg_norms.pth"
data:torch.Tensor = torch.load(fp)
data.shape
# Out:
# torch.Size([409550, 1])

# %%
arr = data.squeeze()

# %%
p_arr = [float(v) for v in arr]

# %%
bins = torch.arange(0, arr.max(), arr.max()/128)
freq = torch.zeros(bins.shape)

for i, _bin in enumerate(bins):

    start = _bin
    if i <= (len(bins) - 2):
        end = bins[i+1]
    else:
        end = 10000

    # number of samples in a bin
    count = ((arr >= start) & (arr < end)).sum()

    freq[i] = count

# %%
relative_freq = (freq) / (freq.sum())
relative_freq
# Out:
# tensor([7.8350e-01, 6.0046e-02, 3.5239e-02, 2.4456e-02, 1.8010e-02, 1.3857e-02,
#         1.0338e-02, 8.5924e-03, 7.0175e-03, 5.6330e-03, 4.6710e-03, 3.9165e-03,
#         3.1889e-03, 2.7909e-03, 2.3489e-03, 1.9998e-03, 1.6213e-03, 1.4626e-03,
#         1.3161e-03, 1.0402e-03, 9.2052e-04, 8.6436e-04, 8.2285e-04, 6.8856e-04,
#         5.7136e-04, 5.5427e-04, 4.4439e-04, 3.7358e-04, 2.7591e-04, 3.3207e-04,
#         2.5394e-04, 2.8812e-04, 2.5638e-04, 2.2708e-04, 2.0754e-04, 1.8313e-04,
#         1.5383e-04, 1.5871e-04, 1.1476e-04, 1.1476e-04, 1.1232e-04, 8.7901e-05,
#         1.0499e-04, 6.5926e-05, 5.6159e-05, 5.6159e-05, 5.1276e-05, 5.8601e-05,
#         4.8834e-05, 2.1975e-05, 3.6626e-05, 3.9067e-05, 5.6159e-05, 4.6392e-05,
#         2.4417e-05, 1.9534e-05, 2.6859e-05, 2.1975e-05, 1.2209e-05, 7.3251e-06,
#         1.7092e-05, 7.3251e-06, 1.7092e-05, 7.3251e-06, 9.7668e-06, 4.8834e-06,
#         2.4417e-06, 1.7092e-05, 7.3251e-06, 9.7668e-06, 0.0000e+00, 2.4417e-06,
#         7.3251e-06, 9.7668e-06, 7.3251e-06, 4.8834e-06, 2.4417e-06, 9.7668e-06,
#         9.7668e-06, 7.3251e-06, 4.8834e-06, 0.0000e+00, 2.4417e-06, 4.8834e-06,
#         0.0000e+00, 0.0000e+00, 0.0000e+00, 2.4417e-06, 2.4417e-06, 4.8834e-06,
#         0.0000e+00, 4.8834e-06, 0.0000e+00, 0.0000e+00, 0.0000e+00, 0.0000e+00,
#         4.8834e-06, 0.0000e+00, 2.4417e-06, 0.0000e+00, 0.0000e+00, 0.0000e+00,
#         0.0000e+00, 0.0000e+00, 0.0000e+00, 0.0000e+00, 0.0000e+00, 0.0000e+00,
#         0.0000e+00, 0.0000e+00, 0.0000e+00, 0.0000e+00, 0.0000e+00, 0.0000e+00,
#         0.0000e+00, 0.0000e+00, 0.0000e+00, 0.0000e+00, 0.0000e+00, 0.0000e+00,
#         0.0000e+00, 0.0000e+00, 0.0000e+00, 0.0000e+00, 0.0000e+00, 0.0000e+00,
#         0.0000e+00, 2.4417e-06])
